# %% [markdown]
# #### Setup

# %% [markdown]
# #### Import the required packages

# %%
from utils.packages import *
# Out:
#  Found and Using 1 GPU

# %%
from utils.data_prep import *

# %%
from utils.modelling import *
from config.variables import *
# Out:
#  Found and Using 1 GPU

# %% [markdown]
# #### Read data

# %%
data["df"] = pd.read_csv('data/UK_Switch_Data.csv')

# %%
df = pd.DataFrame()

# %%
str([1,2])
# Out:
# '[1, 2]'

# %%
x = pd.Series([1])
df['col1'] = x
df['col2'] = str([1,2])

df
# Out:
#    col1    col2
# 0     1  [1, 2]

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Highlevel description of data

# %%
data["df"].head()
# Out:
#    srno  customer_number  customer_id customer_local_key  \
# 0  1549           506550     28898981        UK-C-506550
# 1  1550           506550     28898981        UK-C-506550
# 2  1553           841984     32193564        UK-C-841984
# 3  1554           841984     32193564        UK-C-841984
# 4  1555           850742     32852015        UK-C-850742
#
#             branch_desc_cons business_classification_desc    driver_name  \
# 0     Furniture And Fixtures                  Small fleet    toby downes
# 1     Furniture And Fixtures                  Small fleet    toby downes
# 2         Private Households           Private Households  thomas fosmes
# 3         Private Households           Private Households  thomas fosmes
# 4  Special Trade Contractors                  Small fleet   terry cottam
#
#   start_date_leasecontract end_date_leasecontract leasecontract_status_cons  \
# 0      2014-03-10 00:00:00    2018-04-09 00:00:00                     Ended
# ...

# %%
data['df']['customer_number'].astype('str') + '__text__' + data['df']['customer_local_key']
# Out:
# 0        506550__text__UK-C-506550
# 1        506550__text__UK-C-506550
# 2        841984__text__UK-C-841984
# 3        841984__text__UK-C-841984
# 4        850742__text__UK-C-850742
#                    ...
# 83856    909458__text__UK-C-909458
# 83857    909458__text__UK-C-909458
# 83858      24324__text__UK-C-24324
# 83859      24324__text__UK-C-24324
# 83860      24324__text__UK-C-24324
# Length: 83861, dtype: object

# %%
data["df"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83861 entries, 0 to 83860
# Data columns (total 53 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   srno                          83861 non-null  int64
#  1   customer_number               83861 non-null  int64
#  2   customer_id                   83861 non-null  int64
#  3   customer_local_key            83861 non-null  object
#  4   branch_desc_cons              83861 non-null  object
#  5   business_classification_desc  83861 non-null  object
#  6   driver_name                   83861 non-null  object
#  7   start_date_leasecontract      83861 non-null  object
#  8   end_date_leasecontract        83861 non-null  object
#  9   leasecontract_status_cons     83861 non-null  object
#  10  customer_driver_id            83859 non-null  object
#  11  lease_contract_id             83861 non-null  int64
# ...

# %%
data["df"].describe()
# Out:
#                srno  customer_number   customer_id  lease_contract_id  \
# count  83861.000000     83861.000000  8.386100e+04       8.386100e+04
# mean    1994.856429    203629.617748  2.592449e+07       2.263623e+08
# std     1646.718194    298788.130615  4.104297e+06       8.615307e+07
# min        0.000000        25.000000  2.348585e+07       1.334875e+08
# 25%      593.000000     33373.000000  2.351197e+07       1.459443e+08
# 50%     1575.000000     36877.000000  2.359868e+07       1.803166e+08
# 75%     3097.000000    340638.000000  2.838726e+07       3.055826e+08
# max     6646.000000    915070.000000  4.110804e+07       3.938414e+08
#
#        leasecontract_number    vehicle_id  fuel_consump_manufacturer  \
# count          8.386100e+04  8.386100e+04               83861.000000
# mean           6.021723e+06  3.707787e+08                   1.005546
# std            4.159107e+06  8.270303e+07                   5.516054
# ...

# %% [markdown]
# #### Analyze Features and Observations

# %%
data = analyze_features(data)
# Out:
#   0%|                                                   | 0/53 [00:00<?, ?it/s]
# ---------------------
# customer_local_key : unique vals :  10580
# ---------------------
# ---------------------
# branch_desc_cons : unique vals :  75
# ---------------------
# ---------------------
# business_classification_desc : unique vals :  7
# ---------------------
# ---------------------
# driver_name : unique vals :  27785
# ---------------------
# ---------------------
# start_date_leasecontract : unique vals :  3782
# ---------------------
# ---------------------
# end_date_leasecontract : unique vals :  3459
# ---------------------
# ---------------------
# leasecontract_status_cons : unique vals :  3
# ---------------------
# ---------------------
# customer_driver_id : unique vals :  34379
# ---------------------
# ---------------------
#  36%|██████████████▋                          | 19/53 [00:00<00:00, 188.50it/s]
# vehicle_local_key : unique vals :  83861
# ---------------------
# ...

# %%
data = analyze_observations(data)
# Out:
# ---------------------
# customer_local_key
# UK-C-33373     2914
# UK-C-33646     2589
# UK-C-28067     2240
# UK-C-20871     1897
# UK-C-91770     1674
#                ...
# UK-C-441666       1
# UK-C-444526       1
# UK-C-412016       1
# UK-C-341532       1
# UK-C-437853       1
# Name: customer_local_key, Length: 10580, dtype: int64
# ---------------------
# ---------------------
# branch_desc_cons
# Business Services                                           14307
# Not consolidated                                             7222
# Private Households                                           6729
# Wholesale Trade--Durable Goods                               4923
# Electric, Gas, And Sanitary Services (Private Companies)     4004
#                                                             ...
# Motion Pictures                                                27
# Bitiminous Coal And Lignite Mining                             18
# ...

# %%
data["df"].isnull().sum()
# Out:
# srno                                0
# customer_number                     0
# customer_id                         0
# customer_local_key                  0
# branch_desc_cons                    0
# business_classification_desc        0
# driver_name                         0
# start_date_leasecontract            0
# end_date_leasecontract              0
# leasecontract_status_cons           0
# customer_driver_id                  2
# lease_contract_id                   0
# leasecontract_number                0
# vehicle_id                          0
# vehicle_local_key                   0
# make_cons                           0
# registration_date                   0
# model_cons                          0
# model_type_desc                     0
# manufacturer_group                  0
# vehicle_type_cons                   0
# vehicle_segment_desc                0
# primary_fuel_type_cons              0
# fuel_consump_manufacturer           0
# cat_price_euro                      0
# ...

# %%
data['impute_cols'] = ['working_sector', 'job', 'origin_country']

# %% [markdown]
# ### Data Prep

# %% [markdown]
# #### Pandas Profiling

# %%
profile = ProfileReport(data['df'])
profile.to_file(output_file="output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
